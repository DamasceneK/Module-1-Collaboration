# %%
## 11.1
Created a module zoo.py with a function hours()

# %%
import zoo
zoo.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# ## 11.2
# Imported the zoo module as menagerie and called its hours() function

# %%
import zoo as menagerie
menagerie.hours()
# Out:
# Open 9-5 daily
