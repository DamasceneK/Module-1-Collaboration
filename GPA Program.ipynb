# %%
# Student Honors Checker

while True:
    # Ask for last name
    last_name = input("Enter student's last name (or 'ZZZ' to quit): ")
    
    # Check for exit condition
    if last_name.upper() == 'ZZZ':
        print("Exiting program...")
        break

    # Ask for first name
    first_name = input("Enter student's first name: ")
    
    # Ask for GPA
    try:
        gpa = float(input("Enter student's GPA: "))
    except ValueError:
        print("Invalid GPA. Please enter a numeric value.")
        continue

    # Check Dean's List
    if gpa >= 3.5:
        print(f"{first_name} {last_name} has made the Dean's List.")
    
    # Check Honor Roll
    elif gpa >= 3.25:
        print(f"{first_name} {last_name} has made the Honor Roll.")
    
    else:
        print(f"{first_name} {last_name} did not qualify for honors.")

    print()  # blank line for readability
# Out:
# Enter student's last name (or 'ZZZ' to quit):  kalisa
# Enter student's first name:  damascene
# Enter student's GPA:  3.6
# damascene kalisa has made the Dean's List.
# Enter student's last name (or 'ZZZ' to quit):  zzz
# Exiting program...
